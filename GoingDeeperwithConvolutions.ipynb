# %% [markdown]
# <a href="https://colab.research.google.com/github/CharlesHehe/ML/blob/main/GoingDeeperwithConvolutions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
from keras.layers.core import Layer
import keras.backend as K
import tensorflow as tf
from keras.datasets import cifar10

# %%
from keras.models import Model
from keras.layers import Conv2D, MaxPool2D,  \
    Dropout, Dense, Input, concatenate,      \
    GlobalAveragePooling2D, AveragePooling2D,\
    Flatten

import cv2 
import numpy as np 
from keras.datasets import cifar10 
from keras import backend as K 
from keras.utils import np_utils

import math 
from tensorflow.keras.optimizers import SGD 
from keras.callbacks import LearningRateScheduler

# %%
num_classes = 10

def load_cifar10_data(img_rows, img_cols):

    # Load cifar10 training and validation sets
    (x_train, y_train), (x_test, y_test)  = cifar10.load_data()
    x_train = x_train[:2000,:,:,:]
    x_test = x_test[:400,:,:,:]
    y_train = y_train[:2000,:]
    y_test = y_test[:400,:]


    # Resize training images
    X_train = np.array([cv2.resize(img, (img_rows,img_cols)) for img in x_train[:,:,:,:]])
    X_valid = np.array([cv2.resize(img, (img_rows,img_cols)) for img in x_test[:,:,:,:]])

    # Transform targets to keras compatible format
    Y_train = np_utils.to_categorical(y_train, num_classes)
    Y_valid = np_utils.to_categorical(y_test, num_classes)
    
    X_train = X_train.astype('float32')
    X_valid = X_valid.astype('float32')

    # preprocess data
    X_train = X_train / 255.0
    X_valid = X_valid / 255.0

    return X_train, Y_train, X_valid, Y_valid

X_train, Y_train, X_valid, Y_valid = load_cifar10_data(224,224)

# %%
def inception_module(x,
                     filters_1x1,
                     filters_3x3_reduce,
                     filters_3x3,
                     filters_5x5_reduce,
                     filters_5x5,
                     filters_pool_proj,
                     name=None):
    
    conv_1x1 = Conv2D(filters_1x1, (1, 1), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(x)
    
    conv_3x3 = Conv2D(filters_3x3_reduce, (1, 1), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(x)
    conv_3x3 = Conv2D(filters_3x3, (3, 3), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(conv_3x3)

    conv_5x5 = Conv2D(filters_5x5_reduce, (1, 1), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(x)
    conv_5x5 = Conv2D(filters_5x5, (5, 5), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(conv_5x5)

    pool_proj = MaxPool2D((3, 3), strides=(1, 1), padding='same')(x)
    pool_proj = Conv2D(filters_pool_proj, (1, 1), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(pool_proj)

    output = concatenate([conv_1x1, conv_3x3, conv_5x5, pool_proj], axis=3, name=name)
    
    return output

# %%
kernel_init = keras.initializers.glorot_uniform()
bias_init = keras.initializers.Constant(value=0.2)

# %%
input_layer = Input(shape=(224, 224, 3))

x = Conv2D(64, (7, 7), padding='same', strides=(2, 2), activation='relu', name='conv_1_7x7/2', kernel_initializer=kernel_init, bias_initializer=bias_init)(input_layer)
x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_1_3x3/2')(x)
x = Conv2D(64, (1, 1), padding='same', strides=(1, 1), activation='relu', name='conv_2a_3x3/1')(x)
x = Conv2D(192, (3, 3), padding='same', strides=(1, 1), activation='relu', name='conv_2b_3x3/1')(x)
x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_2_3x3/2')(x)

x = inception_module(x,
                     filters_1x1=64,
                     filters_3x3_reduce=96,
                     filters_3x3=128,
                     filters_5x5_reduce=16,
                     filters_5x5=32,
                     filters_pool_proj=32,
                     name='inception_3a')

x = inception_module(x,
                     filters_1x1=128,
                     filters_3x3_reduce=128,
                     filters_3x3=192,
                     filters_5x5_reduce=32,
                     filters_5x5=96,
                     filters_pool_proj=64,
                     name='inception_3b')

x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_3_3x3/2')(x)

x = inception_module(x,
                     filters_1x1=192,
                     filters_3x3_reduce=96,
                     filters_3x3=208,
                     filters_5x5_reduce=16,
                     filters_5x5=48,
                     filters_pool_proj=64,
                     name='inception_4a')


x1 = AveragePooling2D((5, 5), strides=3)(x)
x1 = Conv2D(128, (1, 1), padding='same', activation='relu')(x1)
x1 = Flatten()(x1)
x1 = Dense(1024, activation='relu')(x1)
x1 = Dropout(0.7)(x1)
x1 = Dense(10, activation='softmax', name='auxilliary_output_1')(x1)

x = inception_module(x,
                     filters_1x1=160,
                     filters_3x3_reduce=112,
                     filters_3x3=224,
                     filters_5x5_reduce=24,
                     filters_5x5=64,
                     filters_pool_proj=64,
                     name='inception_4b')

x = inception_module(x,
                     filters_1x1=128,
                     filters_3x3_reduce=128,
                     filters_3x3=256,
                     filters_5x5_reduce=24,
                     filters_5x5=64,
                     filters_pool_proj=64,
                     name='inception_4c')

x = inception_module(x,
                     filters_1x1=112,
                     filters_3x3_reduce=144,
                     filters_3x3=288,
                     filters_5x5_reduce=32,
                     filters_5x5=64,
                     filters_pool_proj=64,
                     name='inception_4d')


x2 = AveragePooling2D((5, 5), strides=3)(x)
x2 = Conv2D(128, (1, 1), padding='same', activation='relu')(x2)
x2 = Flatten()(x2)
x2 = Dense(1024, activation='relu')(x2)
x2 = Dropout(0.7)(x2)
x2 = Dense(10, activation='softmax', name='auxilliary_output_2')(x2)

x = inception_module(x,
                     filters_1x1=256,
                     filters_3x3_reduce=160,
                     filters_3x3=320,
                     filters_5x5_reduce=32,
                     filters_5x5=128,
                     filters_pool_proj=128,
                     name='inception_4e')

x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_4_3x3/2')(x)

x = inception_module(x,
                     filters_1x1=256,
                     filters_3x3_reduce=160,
                     filters_3x3=320,
                     filters_5x5_reduce=32,
                     filters_5x5=128,
                     filters_pool_proj=128,
                     name='inception_5a')

x = inception_module(x,
                     filters_1x1=384,
                     filters_3x3_reduce=192,
                     filters_3x3=384,
                     filters_5x5_reduce=48,
                     filters_5x5=128,
                     filters_pool_proj=128,
                     name='inception_5b')

x = GlobalAveragePooling2D(name='avg_pool_5_3x3/1')(x)

x = Dropout(0.4)(x)

x = Dense(10, activation='softmax', name='output')(x)

# %%
model = Model(input_layer, [x, x1, x2], name='inception_v1')

# %%
model.summary()
# Out:
# Model: "inception_v1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv_1_7x7/2 (Conv2D)           (None, 112, 112, 64) 9472        input_8[0][0]
# __________________________________________________________________________________________________
# max_pool_1_3x3/2 (MaxPooling2D) (None, 56, 56, 64)   0           conv_1_7x7/2[0][0]
# __________________________________________________________________________________________________
# conv_2a_3x3/1 (Conv2D)          (None, 56, 56, 64)   4160        max_pool_1_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv_2b_3x3/1 (Conv2D)          (None, 56, 56, 192)  110784      conv_2a_3x3/1[0][0]
# __________________________________________________________________________________________________
# max_pool_2_3x3/2 (MaxPooling2D) (None, 28, 28, 192)  0           conv_2b_3x3/1[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 28, 28, 96)   18528       max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 28, 28, 16)   3088        max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 28, 28, 192)  0           max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 28, 28, 64)   12352       max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 28, 28, 128)  110720      conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 28, 28, 32)   12832       conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 28, 28, 32)   6176        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# inception_3a (Concatenate)      (None, 28, 28, 256)  0           conv2d_24[0][0]
#                                                                  conv2d_26[0][0]
#                                                                  conv2d_28[0][0]
#                                                                  conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 28, 28, 128)  32896       inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 28, 28, 32)   8224        inception_3a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 28, 28, 256)  0           inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 28, 28, 128)  32896       inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 28, 28, 192)  221376      conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 28, 28, 96)   76896       conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 28, 28, 64)   16448       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# inception_3b (Concatenate)      (None, 28, 28, 480)  0           conv2d_30[0][0]
#                                                                  conv2d_32[0][0]
#                                                                  conv2d_34[0][0]
#                                                                  conv2d_35[0][0]
# __________________________________________________________________________________________________
# max_pool_3_3x3/2 (MaxPooling2D) (None, 14, 14, 480)  0           inception_3b[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 14, 14, 96)   46176       max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 14, 14, 16)   7696        max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 14, 14, 480)  0           max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 14, 14, 192)  92352       max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 14, 14, 208)  179920      conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 14, 14, 48)   19248       conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 14, 14, 64)   30784       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# inception_4a (Concatenate)      (None, 14, 14, 512)  0           conv2d_36[0][0]
#                                                                  conv2d_38[0][0]
#                                                                  conv2d_40[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 14, 14, 112)  57456       inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 14, 14, 24)   12312       inception_4a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 14, 14, 512)  0           inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 14, 14, 160)  82080       inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 14, 14, 224)  226016      conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 14, 14, 64)   38464       conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 14, 14, 64)   32832       max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# inception_4b (Concatenate)      (None, 14, 14, 512)  0           conv2d_43[0][0]
#                                                                  conv2d_45[0][0]
#                                                                  conv2d_47[0][0]
#                                                                  conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 14, 14, 128)  65664       inception_4b[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 14, 14, 24)   12312       inception_4b[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 14, 14, 512)  0           inception_4b[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 14, 14, 128)  65664       inception_4b[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 14, 14, 256)  295168      conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 14, 14, 64)   38464       conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 14, 14, 64)   32832       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# inception_4c (Concatenate)      (None, 14, 14, 512)  0           conv2d_49[0][0]
#                                                                  conv2d_51[0][0]
#                                                                  conv2d_53[0][0]
#                                                                  conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 14, 14, 144)  73872       inception_4c[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 14, 14, 32)   16416       inception_4c[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 14, 14, 512)  0           inception_4c[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 14, 14, 112)  57456       inception_4c[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 14, 14, 288)  373536      conv2d_56[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 14, 14, 64)   51264       conv2d_58[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 14, 14, 64)   32832       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# inception_4d (Concatenate)      (None, 14, 14, 528)  0           conv2d_55[0][0]
#                                                                  conv2d_57[0][0]
#                                                                  conv2d_59[0][0]
#                                                                  conv2d_60[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 14, 14, 160)  84640       inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 14, 14, 32)   16928       inception_4d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 14, 14, 528)  0           inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 14, 14, 256)  135424      inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 14, 14, 320)  461120      conv2d_63[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 14, 14, 128)  102528      conv2d_65[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 14, 14, 128)  67712       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# inception_4e (Concatenate)      (None, 14, 14, 832)  0           conv2d_62[0][0]
#                                                                  conv2d_64[0][0]
#                                                                  conv2d_66[0][0]
#                                                                  conv2d_67[0][0]
# __________________________________________________________________________________________________
# max_pool_4_3x3/2 (MaxPooling2D) (None, 7, 7, 832)    0           inception_4e[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 7, 7, 160)    133280      max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 7, 7, 32)     26656       max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 7, 7, 832)    0           max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 7, 7, 256)    213248      max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 7, 7, 320)    461120      conv2d_69[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 7, 7, 128)    102528      conv2d_71[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 7, 7, 128)    106624      max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# inception_5a (Concatenate)      (None, 7, 7, 832)    0           conv2d_68[0][0]
#                                                                  conv2d_70[0][0]
#                                                                  conv2d_72[0][0]
#                                                                  conv2d_73[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 7, 7, 192)    159936      inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 7, 7, 48)     39984       inception_5a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 7, 7, 832)    0           inception_5a[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 4, 4, 512)    0           inception_4a[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 4, 4, 528)    0           inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 7, 7, 384)    319872      inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 7, 7, 384)    663936      conv2d_75[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 7, 7, 128)    153728      conv2d_77[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 7, 7, 128)    106624      max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 4, 4, 128)    65664       average_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 4, 4, 128)    67712       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# inception_5b (Concatenate)      (None, 7, 7, 1024)   0           conv2d_74[0][0]
#                                                                  conv2d_76[0][0]
#                                                                  conv2d_78[0][0]
#                                                                  conv2d_79[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2048)         0           conv2d_42[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2048)         0           conv2d_61[0][0]
# __________________________________________________________________________________________________
# avg_pool_5_3x3/1 (GlobalAverage (None, 1024)         0           inception_5b[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1024)         2098176     flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         2098176     flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1024)         0           avg_pool_5_3x3/1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1024)         0           dense[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1024)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 10)           10250       dropout_2[0][0]
# __________________________________________________________________________________________________
# auxilliary_output_1 (Dense)     (None, 10)           10250       dropout[0][0]
# __________________________________________________________________________________________________
# auxilliary_output_2 (Dense)     (None, 10)           10250       dropout_1[0][0]
# ==================================================================================================
# Total params: 10,334,030
# Trainable params: 10,334,030
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
epochs = 25
initial_lrate = 0.01

def decay(epoch, steps=100):
    initial_lrate = 0.01
    drop = 0.96
    epochs_drop = 8
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    return lrate

sgd = SGD(learning_rate=initial_lrate, momentum=0.9, nesterov=False)

lr_sc = LearningRateScheduler(decay, verbose=1)

model.compile(loss=['categorical_crossentropy', 'categorical_crossentropy', 'categorical_crossentropy'], loss_weights=[1, 0.3, 0.3], optimizer=sgd, metrics=['accuracy'])

# %%
history = model.fit(X_train, [Y_train, Y_train, Y_train], validation_data=(X_valid, [Y_valid, Y_valid, Y_valid]), epochs=epochs, batch_size=256, callbacks=[lr_sc])
# Out:
# Epoch 1/25
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.01.
# 8/8 [==============================] - 101s 13s/step - loss: 3.9452 - output_loss: 2.4531 - auxilliary_output_1_loss: 2.4719 - auxilliary_output_2_loss: 2.5015 - output_accuracy: 0.1105 - auxilliary_output_1_accuracy: 0.1080 - auxilliary_output_2_accuracy: 0.0945 - val_loss: 3.7527 - val_output_loss: 2.3663 - val_auxilliary_output_1_loss: 2.3154 - val_auxilliary_output_2_loss: 2.3059 - val_output_accuracy: 0.0825 - val_auxilliary_output_1_accuracy: 0.1200 - val_auxilliary_output_2_accuracy: 0.0900
# Epoch 2/25
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.01.
# 8/8 [==============================] - 104s 13s/step - loss: 3.8056 - output_loss: 2.4051 - auxilliary_output_1_loss: 2.3501 - auxilliary_output_2_loss: 2.3184 - output_accuracy: 0.0900 - auxilliary_output_1_accuracy: 0.0880 - auxilliary_output_2_accuracy: 0.0990 - val_loss: 3.7109 - val_output_loss: 2.3304 - val_auxilliary_output_1_loss: 2.2976 - val_auxilliary_output_2_loss: 2.3041 - val_output_accuracy: 0.0950 - val_auxilliary_output_1_accuracy: 0.1225 - val_auxilliary_output_2_accuracy: 0.0750
# Epoch 3/25
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.01.
# 8/8 [==============================] - 104s 13s/step - loss: 3.7538 - output_loss: 2.3650 - auxilliary_output_1_loss: 2.3142 - auxilliary_output_2_loss: 2.3150 - output_accuracy: 0.1075 - auxilliary_output_1_accuracy: 0.0980 - auxilliary_output_2_accuracy: 0.0960 - val_loss: 3.7084 - val_output_loss: 2.3284 - val_auxilliary_output_1_loss: 2.2969 - val_auxilliary_output_2_loss: 2.3030 - val_output_accuracy: 0.1050 - val_auxilliary_output_1_accuracy: 0.1125 - val_auxilliary_output_2_accuracy: 0.0750
# Epoch 4/25
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.01.
# 8/8 [==============================] - 107s 14s/step - loss: 3.7242 - output_loss: 2.3402 - auxilliary_output_1_loss: 2.3044 - auxilliary_output_2_loss: 2.3090 - output_accuracy: 0.1005 - auxilliary_output_1_accuracy: 0.1085 - auxilliary_output_2_accuracy: 0.0945 - val_loss: 3.6808 - val_output_loss: 2.2999 - val_auxilliary_output_1_loss: 2.2996 - val_auxilliary_output_2_loss: 2.3034 - val_output_accuracy: 0.1125 - val_auxilliary_output_1_accuracy: 0.1125 - val_auxilliary_output_2_accuracy: 0.1125
# Epoch 5/25
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.01.
# 8/8 [==============================] - 100s 12s/step - loss: 3.7260 - output_loss: 2.3439 - auxilliary_output_1_loss: 2.3051 - auxilliary_output_2_loss: 2.3020 - output_accuracy: 0.0880 - auxilliary_output_1_accuracy: 0.0910 - auxilliary_output_2_accuracy: 0.1005 - val_loss: 3.6882 - val_output_loss: 2.3059 - val_auxilliary_output_1_loss: 2.3012 - val_auxilliary_output_2_loss: 2.3064 - val_output_accuracy: 0.0750 - val_auxilliary_output_1_accuracy: 0.0850 - val_auxilliary_output_2_accuracy: 0.0750
# Epoch 6/25
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.01.
# 8/8 [==============================] - 105s 13s/step - loss: 3.7054 - output_loss: 2.3227 - auxilliary_output_1_loss: 2.3036 - auxilliary_output_2_loss: 2.3053 - output_accuracy: 0.1060 - auxilliary_output_1_accuracy: 0.0995 - auxilliary_output_2_accuracy: 0.1150 - val_loss: 3.6831 - val_output_loss: 2.3021 - val_auxilliary_output_1_loss: 2.2996 - val_auxilliary_output_2_loss: 2.3038 - val_output_accuracy: 0.1475 - val_auxilliary_output_1_accuracy: 0.0925 - val_auxilliary_output_2_accuracy: 0.0675
# Epoch 7/25
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.01.
# 8/8 [==============================] - 106s 13s/step - loss: 3.7021 - output_loss: 2.3205 - auxilliary_output_1_loss: 2.3000 - auxilliary_output_2_loss: 2.3053 - output_accuracy: 0.1010 - auxilliary_output_1_accuracy: 0.1170 - auxilliary_output_2_accuracy: 0.0965 - val_loss: 3.6902 - val_output_loss: 2.3103 - val_auxilliary_output_1_loss: 2.2976 - val_auxilliary_output_2_loss: 2.3019 - val_output_accuracy: 0.1050 - val_auxilliary_output_1_accuracy: 0.1150 - val_auxilliary_output_2_accuracy: 0.1000
# Epoch 8/25
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.0096.
# 8/8 [==============================] - 102s 13s/step - loss: 3.7016 - output_loss: 2.3201 - auxilliary_output_1_loss: 2.3002 - auxilliary_output_2_loss: 2.3048 - output_accuracy: 0.1030 - auxilliary_output_1_accuracy: 0.1120 - auxilliary_output_2_accuracy: 0.1040 - val_loss: 3.6766 - val_output_loss: 2.2973 - val_auxilliary_output_1_loss: 2.2951 - val_auxilliary_output_2_loss: 2.3025 - val_output_accuracy: 0.1925 - val_auxilliary_output_1_accuracy: 0.1575 - val_auxilliary_output_2_accuracy: 0.0725
# Epoch 9/25
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.0096.
# 8/8 [==============================] - 103s 13s/step - loss: 3.7020 - output_loss: 2.3219 - auxilliary_output_1_loss: 2.2964 - auxilliary_output_2_loss: 2.3038 - output_accuracy: 0.0995 - auxilliary_output_1_accuracy: 0.1320 - auxilliary_output_2_accuracy: 0.0980 - val_loss: 3.7026 - val_output_loss: 2.3240 - val_auxilliary_output_1_loss: 2.2934 - val_auxilliary_output_2_loss: 2.3017 - val_output_accuracy: 0.0750 - val_auxilliary_output_1_accuracy: 0.1575 - val_auxilliary_output_2_accuracy: 0.0675
# Epoch 10/25
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.0096.
# 8/8 [==============================] - 104s 13s/step - loss: 3.7048 - output_loss: 2.3250 - auxilliary_output_1_loss: 2.2965 - auxilliary_output_2_loss: 2.3026 - output_accuracy: 0.1095 - auxilliary_output_1_accuracy: 0.1240 - auxilliary_output_2_accuracy: 0.1035 - val_loss: 3.6723 - val_output_loss: 2.2953 - val_auxilliary_output_1_loss: 2.2890 - val_auxilliary_output_2_loss: 2.3008 - val_output_accuracy: 0.1375 - val_auxilliary_output_1_accuracy: 0.1600 - val_auxilliary_output_2_accuracy: 0.1125
# Epoch 11/25
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.0096.
# 8/8 [==============================] - 101s 13s/step - loss: 3.6918 - output_loss: 2.3132 - auxilliary_output_1_loss: 2.2917 - auxilliary_output_2_loss: 2.3036 - output_accuracy: 0.1055 - auxilliary_output_1_accuracy: 0.1455 - auxilliary_output_2_accuracy: 0.0995 - val_loss: 3.6726 - val_output_loss: 2.2962 - val_auxilliary_output_1_loss: 2.2858 - val_auxilliary_output_2_loss: 2.3021 - val_output_accuracy: 0.0750 - val_auxilliary_output_1_accuracy: 0.1775 - val_auxilliary_output_2_accuracy: 0.0750
# Epoch 12/25
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.0096.
# 8/8 [==============================] - 97s 12s/step - loss: 3.6802 - output_loss: 2.3034 - auxilliary_output_1_loss: 2.2881 - auxilliary_output_2_loss: 2.3012 - output_accuracy: 0.1095 - auxilliary_output_1_accuracy: 0.1355 - auxilliary_output_2_accuracy: 0.1095 - val_loss: 3.6534 - val_output_loss: 2.2811 - val_auxilliary_output_1_loss: 2.2762 - val_auxilliary_output_2_loss: 2.2980 - val_output_accuracy: 0.1675 - val_auxilliary_output_1_accuracy: 0.1475 - val_auxilliary_output_2_accuracy: 0.0800
# Epoch 13/25
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.0096.
# 8/8 [==============================] - 99s 12s/step - loss: 3.6588 - output_loss: 2.2879 - auxilliary_output_1_loss: 2.2735 - auxilliary_output_2_loss: 2.2961 - output_accuracy: 0.1275 - auxilliary_output_1_accuracy: 0.1535 - auxilliary_output_2_accuracy: 0.1135 - val_loss: 3.6314 - val_output_loss: 2.2661 - val_auxilliary_output_1_loss: 2.2584 - val_auxilliary_output_2_loss: 2.2928 - val_output_accuracy: 0.1825 - val_auxilliary_output_1_accuracy: 0.1725 - val_auxilliary_output_2_accuracy: 0.0850
# Epoch 14/25
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.0096.
# 8/8 [==============================] - 102s 13s/step - loss: 3.6047 - output_loss: 2.2452 - auxilliary_output_1_loss: 2.2464 - auxilliary_output_2_loss: 2.2854 - output_accuracy: 0.1550 - auxilliary_output_1_accuracy: 0.1710 - auxilliary_output_2_accuracy: 0.1310 - val_loss: 3.5295 - val_output_loss: 2.1828 - val_auxilliary_output_1_loss: 2.2129 - val_auxilliary_output_2_loss: 2.2763 - val_output_accuracy: 0.2275 - val_auxilliary_output_1_accuracy: 0.1850 - val_auxilliary_output_2_accuracy: 0.1450
# Epoch 15/25
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.0096.
# 8/8 [==============================] - 108s 14s/step - loss: 3.5426 - output_loss: 2.1945 - auxilliary_output_1_loss: 2.2196 - auxilliary_output_2_loss: 2.2743 - output_accuracy: 0.1845 - auxilliary_output_1_accuracy: 0.1705 - auxilliary_output_2_accuracy: 0.1205 - val_loss: 3.4925 - val_output_loss: 2.1636 - val_auxilliary_output_1_loss: 2.1734 - val_auxilliary_output_2_loss: 2.2562 - val_output_accuracy: 0.2150 - val_auxilliary_output_1_accuracy: 0.1800 - val_auxilliary_output_2_accuracy: 0.1225
# Epoch 16/25
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.009216.
# 8/8 [==============================] - 104s 13s/step - loss: 3.4811 - output_loss: 2.1538 - auxilliary_output_1_loss: 2.1830 - auxilliary_output_2_loss: 2.2415 - output_accuracy: 0.1870 - auxilliary_output_1_accuracy: 0.1830 - auxilliary_output_2_accuracy: 0.1360 - val_loss: 3.3693 - val_output_loss: 2.0838 - val_auxilliary_output_1_loss: 2.0932 - val_auxilliary_output_2_loss: 2.1917 - val_output_accuracy: 0.1675 - val_auxilliary_output_1_accuracy: 0.2675 - val_auxilliary_output_2_accuracy: 0.1625
# Epoch 17/25
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.009216.
# 8/8 [==============================] - 100s 13s/step - loss: 3.5672 - output_loss: 2.2365 - auxilliary_output_1_loss: 2.2008 - auxilliary_output_2_loss: 2.2348 - output_accuracy: 0.1645 - auxilliary_output_1_accuracy: 0.1830 - auxilliary_output_2_accuracy: 0.1610 - val_loss: 3.6035 - val_output_loss: 2.2966 - val_auxilliary_output_1_loss: 2.1529 - val_auxilliary_output_2_loss: 2.2032 - val_output_accuracy: 0.1650 - val_auxilliary_output_1_accuracy: 0.2400 - val_auxilliary_output_2_accuracy: 0.1275
# Epoch 18/25
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.009216.
# 8/8 [==============================] - 101s 13s/step - loss: 3.5146 - output_loss: 2.2072 - auxilliary_output_1_loss: 2.1612 - auxilliary_output_2_loss: 2.1967 - output_accuracy: 0.1565 - auxilliary_output_1_accuracy: 0.1875 - auxilliary_output_2_accuracy: 0.1855 - val_loss: 3.3798 - val_output_loss: 2.1253 - val_auxilliary_output_1_loss: 2.0625 - val_auxilliary_output_2_loss: 2.1190 - val_output_accuracy: 0.2225 - val_auxilliary_output_1_accuracy: 0.2875 - val_auxilliary_output_2_accuracy: 0.2300
# Epoch 19/25
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.009216.
# 8/8 [==============================] - 100s 13s/step - loss: 3.4281 - output_loss: 2.1492 - auxilliary_output_1_loss: 2.1041 - auxilliary_output_2_loss: 2.1588 - output_accuracy: 0.1760 - auxilliary_output_1_accuracy: 0.2255 - auxilliary_output_2_accuracy: 0.1805 - val_loss: 3.2899 - val_output_loss: 2.0653 - val_auxilliary_output_1_loss: 2.0175 - val_auxilliary_output_2_loss: 2.0645 - val_output_accuracy: 0.2425 - val_auxilliary_output_1_accuracy: 0.2800 - val_auxilliary_output_2_accuracy: 0.2500
# Epoch 20/25
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.009216.
# 8/8 [==============================] - 102s 13s/step - loss: 3.3868 - output_loss: 2.1141 - auxilliary_output_1_loss: 2.1140 - auxilliary_output_2_loss: 2.1286 - output_accuracy: 0.1990 - auxilliary_output_1_accuracy: 0.2235 - auxilliary_output_2_accuracy: 0.1830 - val_loss: 3.2665 - val_output_loss: 2.0530 - val_auxilliary_output_1_loss: 2.0000 - val_auxilliary_output_2_loss: 2.0451 - val_output_accuracy: 0.2200 - val_auxilliary_output_1_accuracy: 0.2700 - val_auxilliary_output_2_accuracy: 0.2450
# Epoch 21/25
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.009216.
# 8/8 [==============================] - 105s 13s/step - loss: 3.4047 - output_loss: 2.1388 - auxilliary_output_1_loss: 2.0983 - auxilliary_output_2_loss: 2.1212 - output_accuracy: 0.1895 - auxilliary_output_1_accuracy: 0.2155 - auxilliary_output_2_accuracy: 0.1965 - val_loss: 3.2548 - val_output_loss: 2.0438 - val_auxilliary_output_1_loss: 1.9983 - val_auxilliary_output_2_loss: 2.0384 - val_output_accuracy: 0.2800 - val_auxilliary_output_1_accuracy: 0.2925 - val_auxilliary_output_2_accuracy: 0.2400
# Epoch 22/25
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.009216.
# 8/8 [==============================] - 100s 12s/step - loss: 3.3434 - output_loss: 2.0928 - auxilliary_output_1_loss: 2.0686 - auxilliary_output_2_loss: 2.1001 - output_accuracy: 0.1980 - auxilliary_output_1_accuracy: 0.2175 - auxilliary_output_2_accuracy: 0.2140 - val_loss: 3.2902 - val_output_loss: 2.0730 - val_auxilliary_output_1_loss: 2.0148 - val_auxilliary_output_2_loss: 2.0425 - val_output_accuracy: 0.1775 - val_auxilliary_output_1_accuracy: 0.3025 - val_auxilliary_output_2_accuracy: 0.2300
# Epoch 23/25
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.009216.
# 8/8 [==============================] - 104s 13s/step - loss: 3.3061 - output_loss: 2.0706 - auxilliary_output_1_loss: 2.0482 - auxilliary_output_2_loss: 2.0702 - output_accuracy: 0.2160 - auxilliary_output_1_accuracy: 0.2275 - auxilliary_output_2_accuracy: 0.2065 - val_loss: 3.2162 - val_output_loss: 2.0223 - val_auxilliary_output_1_loss: 1.9751 - val_auxilliary_output_2_loss: 2.0046 - val_output_accuracy: 0.2825 - val_auxilliary_output_1_accuracy: 0.2775 - val_auxilliary_output_2_accuracy: 0.2525
# Epoch 24/25
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.008847359999999999.
# 8/8 [==============================] - 101s 13s/step - loss: 3.2887 - output_loss: 2.0640 - auxilliary_output_1_loss: 2.0302 - auxilliary_output_2_loss: 2.0521 - output_accuracy: 0.2105 - auxilliary_output_1_accuracy: 0.2440 - auxilliary_output_2_accuracy: 0.2285 - val_loss: 3.3329 - val_output_loss: 2.1098 - val_auxilliary_output_1_loss: 2.0174 - val_auxilliary_output_2_loss: 2.0598 - val_output_accuracy: 0.2575 - val_auxilliary_output_1_accuracy: 0.2875 - val_auxilliary_output_2_accuracy: 0.2775
# Epoch 25/25
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.008847359999999999.
# 8/8 [==============================] - 106s 13s/step - loss: 3.2826 - output_loss: 2.0573 - auxilliary_output_1_loss: 2.0324 - auxilliary_output_2_loss: 2.0520 - output_accuracy: 0.2170 - auxilliary_output_1_accuracy: 0.2385 - auxilliary_output_2_accuracy: 0.2225 - val_loss: 3.1732 - val_output_loss: 1.9975 - val_auxilliary_output_1_loss: 1.9436 - val_auxilliary_output_2_loss: 1.9755 - val_output_accuracy: 0.3100 - val_auxilliary_output_1_accuracy: 0.3125 - val_auxilliary_output_2_accuracy: 0.3025

# %%
model.predict(X_valid[0:1,:,:,:])
# X_valid[1].shape
# Out:
# [array([[0.06261056, 0.09983522, 0.13601537, 0.14350127, 0.09824171,
#          0.15363334, 0.06941124, 0.09671443, 0.06077506, 0.07926176]],
#        dtype=float32),
#  array([[0.04987409, 0.07761391, 0.14498492, 0.19667853, 0.09401091,
#          0.18708031, 0.11090576, 0.06582607, 0.03220398, 0.04082149]],
#        dtype=float32),
#  array([[0.04199646, 0.0680221 , 0.13144061, 0.18867847, 0.11103967,
#          0.17193665, 0.10710283, 0.08487107, 0.03510547, 0.05980665]],
#        dtype=float32)]

# %%
model.save("going_deeper_with_convolutions.h5")
